# %%
import sys

sys.path.append('C://Users//kyu//PycharmProjects//maple')

# %%
from pathlib import Path
import pandas as pd
import requests
from bs4 import BeautifulSoup
from maple.nlp.crawler.auto import Automation
from selenium.common.exceptions import UnexpectedAlertPresentException
import re
import time
import random



fpath = Path('/Users/kyu/PycharmProjects/EzCommerce/data/prdNames2.csv')
prd_names = pd.read_csv(fpath).iloc[:, 0].to_list()
lowest_prices = []
lowest_hrefs = []

target_url = 'https://search.shopping.naver.com/search/all.nhn?'
sort_tp = 'price_asc'
# min_price = '0'
# max_price = '19,598'

# %%
MAX_TRY = 5
TIME_WAIT = 2

# %%
crawler = Automation()
for prd in prd_names:
#     query = f'{target_url}query={prd}&sort={sort_tp}&minPrice={min_price}&maxPrice={max_price}'
    url = f'{target_url}query={prd}&sort={sort_tp}'
    html = requests.get(url)
    html_doc = html.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    results = soup.find_all('div', class_='info')
    
#     if len(results):
#         pass
#     else:
#         print(f'Given {prd} is at the lowest price!')
#         continue
    lprice = None
    i = 0
    max_try = max(MAX_TRY, len(results))
    while lprice is None:
        if i == max_try:
            print('==========================')
            print(f" CHECK OUT {prd} MANUALLY ")
            print('==========================')
            break
        print(f'\nFinding lowest price... trial {i}')
        item = results[i]
        
        lprice_href = item.find('a', class_='link').get('href')
        
        if lprice_href.startswith('http://cr2.shopping.naver.com/adcr.nhn'):
            # if goes to another compare page, just skip it
            i += 1
            continue
            
        lprice = re.sub(r'[^\d+]', '', item.find('span', class_='num _price_reload').text) # digits
        lprice_alt = '{:,}'.format(int(lprice))  # digits with marks every thousands
        check = re.compile(f'({lprice}|{lprice_alt})')
        
        print(f'\tFound a candidate lowest price: {lprice}')
#         print(lprice_href)
        
        try:
            crawler.driver.get(lprice_href)

            is_alert, msg = crawler.is_alert()
            if is_alert:
                print(f'\tAlert: {msg}')

            time.sleep(TIME_WAIT + random.random())
            lprice_html = crawler.driver.page_source
            found = check.search(lprice_html)
        
        except UnexpectedAlertPresentException:
            i += 1
            lprice = None
            print(f'\tCandidate Not Found')
            continue
        
        if found is None:
            print(f'\t{lprice} is verfied as ** FAKE **')
            lprice = None
        else:
            print(f'\t{lprice} is verifies as ** REAL **')
            
        i += 1
    if lprice is not None:
        print(f'{prd} --  lowest price: {lprice}')
        lowest_hrefs.append(lprice_href)
    lowest_prices.append(lprice)


assert len(prd_names) == len(lowest_prices) 
assert len(lowest_prices) == len(lowest_hrefs)
# Out:
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 38130
# 	38130 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 38250
# 	38250 is verifies as ** REAL **
# WEP1836PA71 --  lowest price: 38250
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 38130
# 	38130 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 38680
# 	38680 is verfied as ** FAKE **
#
# Finding lowest price... trial 3
# 	Found a candidate lowest price: 40000
# 	Candidate Not Found
#
# Finding lowest price... trial 4
# 	Found a candidate lowest price: 40800
# 	40800 is verfied as ** FAKE **
# ==========================
#  CHECK OUT WEP1837PA71 MANUALLY
# ==========================
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 38130
# 	38130 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 51660
# 	51660 is verfied as ** FAKE **
#
# Finding lowest price... trial 3
# 	Found a candidate lowest price: 53550
# 	53550 is verifies as ** REAL **
# WEP1862FG51 --  lowest price: 53550
#
# Finding lowest price... trial 0
#
# Finding lowest price... trial 1
# 	Found a candidate lowest price: 38660
# 	38660 is verfied as ** FAKE **
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 38940
# 	38940 is verfied as ** FAKE **
#
# Finding lowest price... trial 3
# 	Found a candidate lowest price: 40180
# 	40180 is verifies as ** REAL **
# WEP1986PA11 --  lowest price: 40180
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 39150
# 	39150 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 39760
# 	39760 is verifies as ** REAL **
# WEP1986PA21 --  lowest price: 39760
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 37200
# 	37200 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 38250
# 	38250 is verifies as ** REAL **
# WEP1980PA11 --  lowest price: 38250
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 40000
# 	40000 is verifies as ** REAL **
# WEP1980PA41 --  lowest price: 40000
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 40000
# 	40000 is verifies as ** REAL **
# WEP1980PA81 --  lowest price: 40000
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 38660
# 	38660 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
# 	Found a candidate lowest price: 38660
# 	38660 is verfied as ** FAKE **
#
# Finding lowest price... trial 2
#
# Finding lowest price... trial 3
# 	Found a candidate lowest price: 38670
# 	38670 is verfied as ** FAKE **
#
# Finding lowest price... trial 4
# 	Found a candidate lowest price: 38670
# 	38670 is verfied as ** FAKE **
# ==========================
#  CHECK OUT WEP1981PA11 MANUALLY
# ==========================
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 38660
# 	38660 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 38720
# 	38720 is verfied as ** FAKE **
#
# Finding lowest price... trial 3
# 	Found a candidate lowest price: 38750
# 	38750 is verfied as ** FAKE **
#
# Finding lowest price... trial 4
# 	Found a candidate lowest price: 39350
# 	39350 is verfied as ** FAKE **
# ==========================
#  CHECK OUT WEP1981PA31 MANUALLY
# ==========================
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 38660
# 	38660 is verfied as ** FAKE **
#
# Finding lowest price... trial 1
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 38750
# 	38750 is verfied as ** FAKE **
#
# Finding lowest price... trial 3
# 	Found a candidate lowest price: 39360
# 	39360 is verfied as ** FAKE **
#
# Finding lowest price... trial 4
# 	Found a candidate lowest price: 39990
# 	39990 is verifies as ** REAL **
# WEP1981PA81 --  lowest price: 39990
#
# Finding lowest price... trial 0
# 	Found a candidate lowest price: 46400
# 	46400 is verifies as ** REAL **
# WEP1934GR21 --  lowest price: 46400
#
# Finding lowest price... trial 0
#
# Finding lowest price... trial 1
# 	Found a candidate lowest price: 50220
# 	50220 is verfied as ** FAKE **
#
# Finding lowest price... trial 2
# 	Found a candidate lowest price: 61380
# 	61380 is verfied as ** FAKE **
#
# Finding lowest price... trial 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-14513b2387cd> in <module>
#      22             break
#      23         print(f'\nFinding lowest price... trial {i}')
# ---> 24         item = results[i]
#      25
#      26         lprice_href = item.find('a', class_='link').get('href')
#
# IndexError: list index out of range

# %%
lowest_prices
# Out:
# ['38250',
#  None,
#  '53550',
#  '40180',
#  '39760',
#  '38250',
#  '40000',
#  '40000',
#  None,
#  None,
#  '39990',
#  '46400']
